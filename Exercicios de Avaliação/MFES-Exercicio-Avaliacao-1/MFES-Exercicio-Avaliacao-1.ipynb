# %%
# PG53601
# Afonso Xavier Cardoso Marques
# Mestrado em Engenharia Informática

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------ SAT solvers - Exercício de avaliação -------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------------

# %%
"""
Pretende-se colorir uma sequência de 9 azulejos justapostos com uma paleta de 4 cores: azul, verde, cinzento e preto. A coloração dos azulejos tem que ser feita de acordo com as
seguintes regras:

    1. Cada azulejo tem uma única cor.
    2. Os azulejos das extremidades têm que ter a mesma cor.
    3. Todas as cores têm que ser usadas.
    4. O azulejo do meio só pode ser pintado de cinzento ou preto.
    5. O penúltimo azulejo da sequência tem que ser preto, excepto se o último estiver pintado de preto.
    6. Azulejos seguidos não podem ser pintados da mesma cor.
    7. Caso o primeiro azulejo seja verde e o terceiro não seja preto, o segundo terá que ser cinzento ou preto.
    8. Os azulejos na terceira e na sétima posição só podem ser pintados de azul ou de verde.

Pretende-se codificar este problema em lógica proposicional e usar o Z3 para responder a algumas questões.
"""

# Instalar z3 se necessário
# !pip install z3-solver

# %%
"""
-----------------------------------------------------------------------------------------
EX1) Codifique o problema num solver e comprove que o conjunto de fórmulas é consistente
-----------------------------------------------------------------------------------------
"""

from z3 import *

cores = ["Azul", "Verde", "Cinzento", "Preto"]
azulejos = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# Xca -> onde 'c' é uma cor e 'a' é um azulejo
x = {}
for c in cores:
    x[c] = {}
    for a in azulejos:
        x[c][a] = Bool("%s,%s" % (c, a))

s = Solver()


# Regras para o SAT Solver
# Cada azulejo tem uma única cor
for a in azulejos:
    s.add(Or(x["Azul"][a], x["Verde"][a], x["Cinzento"][a], x["Preto"][a]))
    s.add(Implies(x["Azul"][a], And(Not(x["Verde"][a]), Not(x["Cinzento"][a]), Not(x["Preto"][a]))))
    s.add(Implies(x["Verde"][a], And(Not(x["Azul"][a]), Not(x["Cinzento"][a]), Not(x["Preto"][a]))))
    s.add(Implies(x["Preto"][a], And(Not(x["Verde"][a]), Not(x["Cinzento"][a]), Not(x["Azul"][a]))))
    s.add(Implies(x["Cinzento"][a], And(Not(x["Verde"][a]), Not(x["Azul"][a]), Not(x["Preto"][a]))))

# Azulejos das extremidades têm que ter a mesma cor
for c in cores:
    s.add(Implies(x[c][1], x[c][9]))
    s.add(Implies(x[c][9], x[c][1]))

# Todas as cores têm que ser usadas
for c in cores:
    s.add(Or([x[c][a] for a in azulejos]))

# O azulejo do meio só pode ser cinzento ou preto
s.add(Or(x["Cinzento"][5], x["Preto"][5]))

# O penúltimo azulejo tem que ser preto, exceto se o último estiver pintado de preto
s.add(Or(And(x["Preto"][8], Not(x["Preto"][9])), x["Preto"][9]))

# Azulejos seguidos não podem ser pintados da mesma cor
for a in range(1, 9):
    for c in cores:
        s.add(Implies(x[c][a], Not(x[c][a + 1])))

# Se o primeiro azulejo é verde e o terceiro não é preto, o segundo deve ser cinzento ou preto
s.add(Implies(And(x["Verde"][1], Not(x["Preto"][3])), Or(x["Cinzento"][2], x["Preto"][2])))

# Os azulejos na terceira e na sétima posição só podem ser azul ou verde
s.add(Or(x["Azul"][3], x["Verde"][3]))
s.add(Or(x["Azul"][7], x["Verde"][7]))


# Verificar se as regras são satisfazíveis
if s.check() == sat:
    print("O conjunto de regras é consistente.")

else:
    print("O conjunto de regras é inconsistente.")
# Out:
# O conjunto de regras é consistente.

# %%
"""
-----------------------------------------------------------------------------------------
EX2) Com a ajuda do solver, pronuncie-se quanto à veracidade das seguintes afirmaçõess:
        (a) Se o primeiro azulejo for preto, o penúltimo azulejo tem que ser azul.
        (b) Algum dos dois últimos azulejos tem que ser preto.
        (c) Algum dos três primeiros azulejos poderá ser azul.
-----------------------------------------------------------------------------------------
"""

from z3 import *

# ---a)---
print("a) Se o primeiro azulejo for preto, o penúltimo azulejo tem que ser azul.")

re14 = Implies(x["Preto"][1], x["Azul"][8])
s.add(re14)


if s.check() == sat:
        print("É verdade!")
        print("\n")
else:
        print("É falso!")
        print("\n")

# ---b)---
print("b) Algum dos dois últimos azulejos tem que ser preto.")

re15 = Or(x["Preto"][8], x["Preto"][9])
s.add(re15)

if s.check() == sat:
        print("É verdade!")
        print("\n")
else:
        print("É falso!")
        print("\n")

# ---c)---
print("c) Algum dos três primeiros azulejos poderá ser azul.")

re16 = Or(x["Azul"][1], x["Azul"][2], x["Azul"][3])
s.add(re16)


if s.check() == sat:
        print("É verdade!")
        print("\n")
else:
        print("É falso!")
        print("\n")
# Out:
# a) Se o primeiro azulejo for preto, o penúltimo azulejo tem que ser azul.
# É verdade!
#
#
# b) Algum dos dois últimos azulejos tem que ser preto.
# É verdade!
#
#
# c) Algum dos três primeiros azulejos poderá ser azul.
# É verdade!

# %%
"""
-----------------------------------------------------------------------------------------
EX3) Acrescente código ao programa de modo a saber todas as colorações que são
     possíveis fazer aos azulejos. Quantas são?
-----------------------------------------------------------------------------------------
"""

from z3 import *

s.push()

num_solucoes = 0

while s.check() == sat:
    m = s.model()

    combinacao = ""
    print("Comb%d" % (num_solucoes+1))
    combinacao += " | "

    for a in azulejos:
        for c in cores:
            if is_true(m[x[c][a]]):
                #print("Azulejo %d é %s" % (a,c))
                combinacao += a.__str__()
                combinacao += ". "
                combinacao += c
                combinacao += " | "


    print(combinacao)
    print("-----------------------------------------------------------------------------------------------------------")
    num_solucoes += 1

    restricao = []
    for a in azulejos:
        for c in cores:
            if is_true(m[x[c][a]]):
                restricao.append(Not(x[c][a]))
    s.add(Or(restricao))


else:
    if num_solucoes < 0:
        print("Não tem solução.")
    else:
        print()
        print("Encontradas %d combinações para os azulejos" % (num_solucoes))

s.pop()
# Out:
# Comb1
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb2
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb3
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb4
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb5
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb6
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb7
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb8
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb9
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb10
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb11
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb12
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb13
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb14
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb15
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb16
#  | 1. Azul | 2. Cinzento | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb17
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb18
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb19
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb20
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb21
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb22
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb23
#  | 1. Azul | 2. Preto | 3. Verde | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb24
#  | 1. Azul | 2. Preto | 3. Verde | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb25
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb26
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb27
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb28
#  | 1. Azul | 2. Preto | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb29
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb30
#  | 1. Azul | 2. Preto | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb31
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb32
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb33
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb34
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb35
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb36
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb37
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb38
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb39
#  | 1. Azul | 2. Preto | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb40
#  | 1. Azul | 2. Preto | 3. Verde | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb41
#  | 1. Azul | 2. Preto | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb42
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb43
#  | 1. Azul | 2. Preto | 3. Verde | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb44
#  | 1. Azul | 2. Preto | 3. Verde | 4. Azul | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb45
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb46
#  | 1. Cinzento | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb47
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb48
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb49
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb50
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb51
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb52
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb53
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb54
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb55
#  | 1. Verde | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb56
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb57
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb58
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb59
#  | 1. Verde | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb60
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb61
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb62
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb63
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb64
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb65
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb66
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb67
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb68
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb69
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb70
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb71
#  | 1. Verde | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb72
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb73
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb74
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb75
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb76
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb77
#  | 1. Verde | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb78
#  | 1. Azul | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb79
#  | 1. Azul | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb80
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb81
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb82
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb83
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb84
#  | 1. Azul | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb85
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb86
#  | 1. Azul | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb87
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb88
#  | 1. Azul | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb89
#  | 1. Azul | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb90
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb91
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb92
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb93
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Verde | 7. Azul | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb94
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb95
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb96
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb97
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb98
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb99
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb100
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb101
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb102
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb103
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb104
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb105
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb106
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb107
#  | 1. Cinzento | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb108
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb109
#  | 1. Verde | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb110
#  | 1. Verde | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb111
#  | 1. Verde | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb112
#  | 1. Verde | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb113
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb114
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb115
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb116
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb117
#  | 1. Azul | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb118
#  | 1. Azul | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb119
#  | 1. Azul | 2. Preto | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb120
#  | 1. Verde | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb121
#  | 1. Azul | 2. Preto | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb122
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb123
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb124
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb125
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb126
#  | 1. Verde | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Verde |
# -----------------------------------------------------------------------------------------------------------
# Comb127
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb128
#  | 1. Azul | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb129
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb130
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb131
#  | 1. Cinzento | 2. Preto | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Cinzento |
# -----------------------------------------------------------------------------------------------------------
# Comb132
#  | 1. Azul | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb133
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb134
#  | 1. Azul | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb135
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb136
#  | 1. Azul | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb137
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb138
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb139
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb140
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb141
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb142
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb143
#  | 1. Azul | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb144
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb145
#  | 1. Azul | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb146
#  | 1. Azul | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Preto | 9. Azul |
# -----------------------------------------------------------------------------------------------------------
# Comb147
#  | 1. Preto | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb148
#  | 1. Preto | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb149
#  | 1. Preto | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb150
#  | 1. Preto | 2. Azul | 3. Verde | 4. Azul | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb151
#  | 1. Preto | 2. Azul | 3. Verde | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb152
#  | 1. Preto | 2. Azul | 3. Verde | 4. Azul | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb153
#  | 1. Preto | 2. Azul | 3. Verde | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb154
#  | 1. Preto | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb155
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb156
#  | 1. Preto | 2. Verde | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb157
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Cinzento | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb158
#  | 1. Preto | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb159
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb160
#  | 1. Preto | 2. Verde | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb161
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Preto | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb162
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb163
#  | 1. Preto | 2. Verde | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb164
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Verde | 5. Preto | 6. Cinzento | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb165
#  | 1. Preto | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb166
#  | 1. Preto | 2. Verde | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb167
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Azul | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
# Comb168
#  | 1. Preto | 2. Cinzento | 3. Azul | 4. Verde | 5. Cinzento | 6. Preto | 7. Verde | 8. Azul | 9. Preto |
# -----------------------------------------------------------------------------------------------------------
#
# Encontradas 168 combinações para os azulejos
